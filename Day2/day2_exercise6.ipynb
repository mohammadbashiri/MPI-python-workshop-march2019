# %% [markdown]
# Practice Pandas (long exercise).
#
# This exercise is going to be on the wine dataset. And on day 3 we will use other Pandas features and seaborn to build on top of our exploration of wine quality, and the relavant features.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# 1) Create a Pandas DataFrame where each column accommodates the following 1D Numpy arrays

# %%
col1 = np.random.rand(5)
col2 = np.random.rand(5)

# %%
pd.DataFrame({'col1': col1, 
              'col2': col2})
# Out:
#        col1      col2
# 0  0.547689  0.689309
# 1  0.394510  0.570960
# 2  0.982208  0.433027
# 3  0.002166  0.914341
# 4  0.797900  0.391140

# %% [markdown]
# 2) Create a Pandas DataFrame from the  following 2D array (shape = 5x2), with column names 'col1' and 'col2'.

# %%
data = np.random.rand(5, 2)

# %%
pd.DataFrame(data, columns=['col1', 'col2'])
# Out:
#        col1      col2
# 0  0.013863  0.747172
# 1  0.046939  0.658362
# 2  0.867280  0.503842
# 3  0.856819  0.175071
# 4  0.901461  0.196484

# %% [markdown]
# 3) I have shared with you the wine DataSet on **Slack > data**. Please download the data and import it into your Notebook. and display the first 10 rows.

# %%
df = pd.read_csv("data/wine-rw.csv")

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  total sulfur dioxide  alcohol  quality  \
# 0            7.4              0.70                  34.0      9.4        5
# 1            7.8              0.88                  67.0      9.8        5
# 2            7.8              0.76                  54.0      9.8        5
# 3           11.2              0.28                  60.0      9.8        6
# 4            7.4              0.70                  34.0      9.4        5
#
#   color
# 0   red
# 1   red
# 2   red
# 3   red
# 4   red

# %% [markdown]
# 4) Display the last 15 rows of the DataFrame.

# %%
df.tail(15)
# Out:
#       fixed acidity  volatile acidity  total sulfur dioxide  alcohol  quality  \
# 6482            4.9             0.470                 148.0    11.50        6
# 6483            6.5             0.330                 174.0     9.60        5
# 6484            6.6             0.340                 170.0     9.55        6
# 6485            6.2             0.210                 121.0    12.15        7
# 6486            6.2             0.410                  56.0    13.00        7
# 6487            6.8             0.220                 127.0     9.20        5
# 6488            4.9             0.235                 118.0     9.40        6
# 6489            6.1             0.340                 100.0    11.80        6
# 6490            5.7             0.210                 121.0    10.60        6
# 6491            6.5             0.230                 112.0     9.70        5
# 6492            6.2             0.210                  92.0    11.20        6
# ...

# %% [markdown]
# 5) How many rows and columns does the DataFrame have?

# %%
df.shape
# Out:
# (6497, 6)

# %% [markdown]
# 6) What is the datatype of each column?

# %%
df.dtypes
# Out:
# fixed acidity           float64
# volatile acidity        float64
# total sulfur dioxide    float64
# alcohol                 float64
# quality                   int64
# color                    object
# dtype: object

# %% [markdown]
# 7) Get the following two columns as separate Numpy arrays:
# - `fixed_acidity`
# - `alcohol`

# %% [markdown]
# 8) Plot the two Numpy array versus each other with a scatter plot.

# %%
sns.pairplot(df[['fixed acidity', 'volatile acidity', 'total sulfur dioxide', 'alcohol', 'quality', 'color']], hue='color')

# %%
df.dtypes
# Out:
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# color                    object
# dtype: object

# %%
sns.violinplot(data=df, x='quality', y='alcohol', hue='color', split=True)

# %%
sns.catplot(data=df, x='quality', y='alcohol', hue='color', kind='point')

# %%
# Plot miles per gallon against horsepower with other semantics
sns.relplot(data=df, x="fixed acidity", y="total sulfur dioxide", hue="color", size="quality",
            sizes=(40, 400), alpha=.5, palette="muted",
            height=6)

# %%
plt.cm.bwr(np.arange(1, 100))[:, :-1].shape
# Out:
# (99, 3)

# %%
color = plt.cm.viridis(np.linspace(0, 255, len(df.quality.unique())).astype(np.int))

# %%
plt.scatter(np.arange(7), np.arange(7), c=color)

# %%
colors = np.array([color[el-3, :-1] for el in df.quality.values])

# %%
colors.shape
# Out:
# (6497, 3)

# %%
plt.scatter(df['fixed acidity'], df['total sulfur dioxide'], c=colors, alpha=.5)

# %% [markdown]
# df.columns

# %%
sns.pairplot(df_red[['citric acid', 'free sulfur dioxide', ]])

# %% [markdown]
# ---

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('data/wine-rw.csv')

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  total sulfur dioxide  alcohol  quality  \
# 0            7.4              0.70                  34.0      9.4        5
# 1            7.8              0.88                  67.0      9.8        5
# 2            7.8              0.76                  54.0      9.8        5
# 3           11.2              0.28                  60.0      9.8        6
# 4            7.4              0.70                  34.0      9.4        5
#
#   color
# 0   red
# 1   red
# 2   red
# 3   red
# 4   red

# %%
np.sort(df.quality.unique())
# Out:
# array([3, 4, 5, 6, 7, 8, 9])

# %%
my_dict = {3:'low', 4:'low', 5:'medium', 6:'medium', 7:'medium', 8:'high', 9:'high'}

# %%
df['quality_cat'] = [my_dict[el] for el in df.quality.values]

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  total sulfur dioxide  alcohol  quality  \
# 0            7.4              0.70                  34.0      9.4        5
# 1            7.8              0.88                  67.0      9.8        5
# 2            7.8              0.76                  54.0      9.8        5
# 3           11.2              0.28                  60.0      9.8        6
# 4            7.4              0.70                  34.0      9.4        5
#
#   color quality_cat
# 0   red      medium
# 1   red      medium
# 2   red      medium
# 3   red      medium
# 4   red      medium

# %%
sns.catplot(data=df, x = 'quality_cat', y='alcohol', kind='violin', hue='color', split=True)

# %% [markdown]
# ## Apply: Make standard deviation equal to one (without moving the mean)

# %%
fig, ax = plt.subplots()
for col in ['fixed acidity', 'volatile acidity', 'total sulfur dioxide', 'alcohol']:
    sns.distplot(df[col], ax=ax)

# %%
df_norm = df[['fixed acidity', 'volatile acidity', 'total sulfur dioxide', 'alcohol']].apply(lambda x: (x - x.mean()) / x.std())

# %%
fig, ax = plt.subplots()
for col in ['fixed acidity', 'volatile acidity', 'total sulfur dioxide', 'alcohol']:
    sns.distplot(df_norm[col], ax=ax)

# %% [markdown]
# ## Groupby-apply: Do the same as before but for every wine color

# %%
df_norm.head()
# Out:
#    fixed acidity  volatile acidity  total sulfur dioxide   alcohol
# 0       0.142462          2.188664             -1.446247 -0.915394
# 1       0.451001          3.281982             -0.862402 -0.580023
# 2       0.451001          2.553104             -1.092402 -0.580023
# 3       3.073580         -0.362411             -0.986248 -0.580023
# 4       0.142462          2.188664             -1.446247 -0.915394

# %%
attributes = ['fixed acidity', 'volatile acidity', 'total sulfur dioxide', 'alcohol']

# %%
df.groupby('color')[attributes]

# %% [markdown]
# ## Groupby-agg: mean alcohol value based on quality!

# %%
df.groupby('quality_cat')['alcohol'].agg([np.mean, np.std, np.min, np.max, len])
# Out:
#                   mean       std  amin  amax     len
# quality_cat
# high         11.691414  1.273262   8.5  14.0   198.0
# low          10.184350  0.999035   8.0  13.5   246.0
# medium       10.465055  1.175632   8.0  14.9  6053.0
