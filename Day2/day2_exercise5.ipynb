# %% [markdown]
# This exercise is concerned with practicing Numpy and matplotlib (once they are both finished)
# - Make group of two people
# - work on the data alone and together
# - answer the following questions
# - send you figures to me

# %%
np.load("data/alcohol.npy")
# Out:
# array([ 8.8,  9.5, 10.1, ...,  9.4, 12.8, 11.8])

# %%
np.load("data/Residual_Sugar.npy")
# Out:
# array([20.7,  1.6,  6.9, ...,  1.2,  1.1,  0.8])

# %%
plt.scatter(np.load("data/alcohol.npy"), np.load("data/Residual_Sugar.npy"), c=np.load("data/quality.npy")*10, alpha=.1)
