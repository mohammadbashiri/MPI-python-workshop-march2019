# %% [markdown]
# 1) Create a numpy array ranging from 0 to $2\pi$ (use `np.pi`) with size 1000. Name it `my_arr`.

# %%
my_arr = np.linspace(0, 2*np.pi, 1000)

# %% [markdown]
# 2) Compute the sine and cosine of the values of `my_arr`. Name them `sin_arr` and `cos_arr`, respectively.

# %%
sin_arr = np.sin(my_arr)
cos_arr = np.cos(my_arr)

# %% [markdown]
# 3) Plot both `sin_arr` and `cos_arr` on the same plot, versis angle (`my_arr`).

# %%
plt.plot(my_arr, sin_arr)
plt.plot(my_arr, cos_arr)

# %% [markdown]
# 4) Plot the previous plot, and perform the following task:
# - add label to the x-axis and y-axis accordingly.
# - change the line colors (red for sin and green for cosine)
# - make the lines thicker
# - change the line styles to dashed for sin and dotted for cos
# - add legends to the plot
# - increase the fontsize of x-axis and y-axis label
# - increase the fintsize of the tickmarks

# %% [markdown]
# 5) Find the minim of each of the arrays, and draw a vertical line at those points

# %% [markdown]
# 6) plot the following two numpy arrays versus each other

# %%
a_arr_1 = np.random.randn(10000) / 2
b_arr_1 = np.random.randn(10000) / 5

# %%
plt.scatter(a_arr_1, b_arr_1);

# %% [markdown]
# 7) Plot the `a_arr_1` vs `b_arr_1` and `a_arr_2` vs `b_arr_2` on the same plot.

# %%
a_arr_2 = np.random.randn(10000)
b_arr_2 = np.random.randn(10000)

# %%
plt.scatter(a_arr_1, b_arr_1);
plt.scatter(a_arr_2, b_arr_2);

# %% [markdown]
# Can you see both datasets?
#
# 8) Use the features of the plot such as `size`, `color`, and `alpha` values to make the datasets visible.

# %%
plt.scatter(a_arr_1, b_arr_1, s=20, alpha=.01);
plt.scatter(a_arr_2, b_arr_2, s=20, alpha=.01);
