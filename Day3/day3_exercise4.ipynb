# %% [markdown]
# - [ ] [C] [30] Seaborn

# %%
df = pd.read_csv('MPI-info.csv')

# %%
sns.pairplot(df[['age', 'papers', 'citations', 'colleagues', 'sex']], hue='sex')

# %%
sns.pairplot(df[['age', 'papers', 'citations', 'colleagues', 'coffees', 'MPI']], hue='MPI')

# %%
sns.catplot(data=df, x='sex', y='papers', kind='violin', hue='MPI', split=True);
ax = plt.gca()
ax.set_ylabel("hello", fontsize=20)
# Out:
# Text(30.622656250000013, 0.5, 'hello')
